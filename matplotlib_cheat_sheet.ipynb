# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
data2 = 3 * np.random.random((10, 10))

# %%
data2
# Out:
# array([[2.43826503, 1.45883133, 2.14456621, 0.33593279, 2.51915419,
#         2.68187525, 0.81726032, 2.3083369 , 1.39276495, 1.50708569],
#        [0.46342642, 2.08080535, 1.88752974, 1.49150307, 1.53400921,
#         0.77316688, 1.42192647, 0.96751817, 0.68857269, 0.09506618],
#        [2.37718631, 0.28751823, 0.75989007, 2.80435931, 2.11119725,
#         1.69130164, 0.10866645, 1.61437216, 1.89696946, 2.52401893],
#        [1.68483496, 1.47009281, 0.5445801 , 0.23684118, 1.72880627,
#         0.5850445 , 2.33255937, 0.81551819, 2.86372682, 2.12994212],
#        [0.34531595, 0.76087055, 2.44888832, 2.32027895, 1.00622161,
#         1.33834552, 0.84225723, 1.53564416, 0.95805177, 2.70419589],
#        [2.39609944, 0.20727045, 1.96599069, 0.59333283, 1.50678555,
#         2.36953239, 0.52055432, 1.26850077, 0.52761193, 2.35014172],
#        [2.72978743, 2.27774145, 0.76025106, 1.47026592, 1.00752081,
#         0.83302833, 1.68738284, 1.00603833, 0.68826088, 2.69521391],
#        [0.21859836, 1.75301591, 2.70932304, 1.71142553, 2.87533912,
#         1.97417062, 2.01215498, 1.06855292, 1.17631434, 1.17888663],
#        [2.02570218, 2.38141192, 1.92050414, 1.42325789, 0.63202015,
#         1.92410562, 2.98625637, 0.74034118, 1.22728192, 2.78624881],
#        [1.30027723, 1.41625398, 2.53964621, 0.11537037, 0.53145614,
#         0.11951977, 0.39029117, 0.33152155, 1.61232873, 1.07084655]])

# %%
matplotlib.__version__
# Out:
# '3.2.2'

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints,'o')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])

plt.plot(xpoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
# 'r'	Red	
# 'g'	Green	
# 'b'	Blue	
# 'c'	Cyan	
# 'm'	Magenta	
# 'y'	Yellow	
# 'k'	Black	
# 'w'	White



#mec=marker color
#mfc=marker face color

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o--r',ms=20,mec='k',mfc='c',linewidth = '2.5')

plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.title("Sports Watch Data")
# Out:
# Text(0.5, 1.0, 'Sports Watch Data')

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'red','size':15}

plt.title("Sports Watch Data", fontdict = font1,loc = 'left')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5,axis='y')

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5,axis='x')

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 3)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.suptitle("MY SHOP")
# Out:
# Text(0.5, 0.98, 'MY SHOP')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10* np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = np.random.randint(10, size=(10))
y = np.random.randint(100, size=(10))
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
x
# Out:
# array([2, 5, 9, 0, 0, 6, 2, 1, 4, 2])

# %%
y
# Out:
# array([98, 95, 72, 83, 71,  7,  5, 80, 90,  8])

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y,height = 0.1)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red", width = 0.1)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.random.normal(170, 10, 250)

# %%
plt.hist(x)
# Out:
# (array([ 7., 12., 21., 42., 51., 49., 28., 27., 12.,  1.]),
#  array([143.98770569, 149.23232119, 154.47693669, 159.72155219,
#         164.96616769, 170.21078319, 175.45539869, 180.70001419,
#         185.94462969, 191.1892452 , 196.4338607 ]),
#  <a list of 10 Patch objects>)

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x21601d71d30>,
#   <matplotlib.patches.Wedge at 0x21601d7f220>,
#   <matplotlib.patches.Wedge at 0x21601d7f6a0>,
#   <matplotlib.patches.Wedge at 0x21601d7fb20>],
#  [Text(0.4993895680663529, 0.9801071672559597, ''),
#   Text(-1.086457168210212, 0.17207795223283895, ''),
#   Text(-0.172077952232839, -1.086457168210212, ''),
#   Text(0.9801071672559598, -0.4993895680663526, '')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x21601dc3340>,
#   <matplotlib.patches.Wedge at 0x21601dc37f0>,
#   <matplotlib.patches.Wedge at 0x21601dc3c70>,
#   <matplotlib.patches.Wedge at 0x21601dd0130>],
#  [Text(0.4993895680663529, 0.9801071672559597, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283895, 'Bananas'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherries'),
#   Text(0.9801071672559598, -0.4993895680663526, 'Dates')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode,shadow = True)
plt.legend(title = "Four Fruits",loc='upper left')

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2160333ddf0>,
#   <matplotlib.lines.Line2D at 0x2160334a190>],
#  'caps': [<matplotlib.lines.Line2D at 0x2160334a4f0>,
#   <matplotlib.lines.Line2D at 0x2160334a850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2160333da90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2160334abb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2160334aeb0>],
#  'means': []}
